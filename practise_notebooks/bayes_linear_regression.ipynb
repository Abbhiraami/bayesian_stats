# %%
pip install -U "jax[cpu]"
# Out:
# ...
#   Using cached jax-0.3.25-py3-none-any.whl
# ...
# INFO: pip is looking at multiple versions of jax[cpu] to determine which version is compatible with other requirements. This could take a while.
#   Using cached jax-0.3.24.tar.gz (1.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Using cached jax-0.3.23.tar.gz (1.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
# !pip install -q flax>=0.7.5
# !pip install jax>=0.4.14
# !pip install numpyro==0.13.2

# %%
import numpyro
import jax
# !pip install jaxlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_936\949352260.py in <module>
# ----> 1 import numpyro
#       2 import jax
#       3 # !pip install jaxlib
#
# ModuleNotFoundError: No module named 'numpyro'

# %%
import numpyro
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_936\725327628.py in <module>
# ----> 1 import numpyro
#
# ModuleNotFoundError: No module named 'numpyro'

# %%
# !pip install -q numpyro@git+https://github.com/pyro-ppl/numpyro

# %%
import numpyro
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24644\725327628.py in <module>
# ----> 1 import numpyro
#
# ModuleNotFoundError: No module named 'numpyro'

# %%
pip install -r "C:\Users\SHAMBHAVVISEN\bayesian\env_scripts\jax_requirements.txt"
# Out:
# ...
#   Using cached tensorflow_probability-0.15.0-py2.py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached type_extensions-0.1.2-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached msgpack-1.0.0-cp37-cp37m-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached PyYAML-6.0-cp37-cp37m-win_amd64.whl.metadata (2.0 kB)
# ...
#   Using cached optax-0.1.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached chex-0.1.3-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached toolz-0.10.0.tar.gz (49 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import jax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24644\1918681042.py in <module>
# ----> 1 import jax
#
# c:\users\shambhavvisen\appdata\local\programs\python\python37\lib\site-packages\jax\__init__.py in <module>
#      19
#      20 # flake8: noqa: F401
# ---> 21 from .config import config
#      22 from .api import (
#      23   ad,  # TODO(phawkins): update users to avoid this.
#
# c:\users\shambhavvisen\appdata\local\programs\python\python37\lib\site-packages\jax\config.py in <module>
#      17 import threading
#      18 from typing import Optional
# ---> 19 from jax import lib
#      20
#      21 def bool_env(varname: str, default: bool) -> bool:
#
# c:\users\shambhavvisen\appdata\local\programs\python\python37\lib\site-packages\jax\lib\__init__.py in <module>
#      21 ]
#      22
# ---> 23 import jaxlib
#      24
# ...
